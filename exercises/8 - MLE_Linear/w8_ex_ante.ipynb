# %% [markdown]
# # Setup

# %%
# general modules 
import numpy as np
import pandas as pd 
from matplotlib import pyplot as plt
from scipy.optimize import minimize

# %load_ext autoreload
# %autoreload 2
 
# Code for this week 
import estimation_ante as est
import LinearModel_ante as lm # based on code from previous weeks

# Set random seed
seed = 42
rng = np.random.default_rng(seed=seed)

# %%
import seaborn as sns
sns.set_theme()
plt.rcParams.update({
    #"text.usetex": True, # LaTeX can sometimes be tricky to get working but makes graphs prettier :) 
    "font.family": "serif", 
    "font.size":18 
})

# %% [markdown]
# # Maximum Likelihood Estimation of the Linear Model
#
#
# In this exercise we will consider the linear regression model. Of
# course, when estimated with OLS, the estimator, which minimizes the sum
# of squared residuals, has a closed form solution. This also goes for the
# maximum likelihood estimator when the residuals are assumed Gaussian. We
# will however do the maximization numerically using the scipy library and the `optimize` class, more specifically we will use its `minimize` function. The purpose of this exercise is to learn to do
# numerical maximization and to be familiar with $M$-estimators by viewing
# the maximum likelihood estimator of the linear model as an
# $M$-estimator.
#
# ## The Model
#
# We consider a linear model with the following characteristics
#
# $$y_{i}=\beta _{0}+\beta _{1}x_{1i}+....+\beta _{k-1}x_{k-1i}+u _{i} \quad i=1,..,N$$
#
# with $u_{i} \sim N(0,\sigma^2)$.

# %% [markdown]
# The (conditional) likelihood contribution for observation $i$ is,
# $$f\left(y_{i}\left|\mathbf{x}_{i};\beta,\sigma^{2}\right.\right) = \phi\left(\frac{\hat{u}_i}{\sigma}\right) =\frac{1}{\sqrt{2\pi\sigma^{2}}}\exp\left\{ -\frac{1}{2}\frac{\hat{u}_{i}^{2}}{\sigma^{2}}\right\},$$
# where
# $\hat{u}_{i}=y_{i}- \sum_{k=1}^K \beta_k x_{ik}$, and $\phi(\cdot)$ is the standard normal density.
#
# Thus, the loglikelihood contribution is
# $$
#  \ell_i(\theta) = - \frac{1}{2}\log (2 \pi) - \frac{1}{2}\log(\sigma^2) - \frac{1}{2}\frac{\hat{u}_i^2}{\sigma^2}
# $$
#
# Often the term $-\frac{1}{2}\log\left(2\pi\right)$ is dropped as it does not change with
# $\beta$ or $\sigma$ and thus does not affect the optimization.
#
# Finally, our optimizer will be solving the problem
# $$ \min_\theta \frac{1}{N} \sum_{i=1}^N q(\theta, y_i, x_i),$$
# where the criterion function is the negative loglikelihood contribution, $q(\theta,y_i,x_i) = - \ell_i(\theta)$.
# Again, we can drop the factor $N^{-1}$ as it does not affect the optimization.

# %%
# Simulate dataset
n = 100
K = 2 # two regressors, a constant and one (real) regressor
beta = np.ones((K,1))  # First is constant
sigma = 3
true_theta = np.vstack([beta, sigma])
y, x = lm.sim_data(n, true_theta, rng)

# Find some starting values 
theta0 = lm.starting_values(y, x, ) # returns OLS estimates as candidate starting values
theta0 = 0.8*theta0 # scale them by 0.8 to make the problem a little harder

# %%
true_theta
# Out:
# array([[1.],
#        [1.],
#        [3.]])

# %% [markdown]
# # Question 1: Write a function for the likelihood contribution.
# Open the file `LinearModel.py`, and fill in the function `loglikelihood` with the **likelihood contribution**. It should return an $N \times 1$ vector of likelihood contributions.
#
# *Hint:* The sum of the likelihood contributions should be close to -162.8, given `theta0, x, y`, which I have written a function to check for you, so you know if you have written it correctly.

# %%
# Fill in the missing parts of the lm.loglikelihood() function.
# First, calculate the residual.
# Then calculate the likelihood value, using the likelihood contribution equation from above.
# Test if you got it right with the cell below. You might have to "reseed" by running the first cell in this notebook again.

# %%
np.isclose(np.sum(lm.loglikelihood(theta0, y, x)), -162.800)
# Out:
# True

# %% [markdown]
# # Question 2: Estimate Parameters
#
# Now finish up the `estimation` function, which takes a function to minimize `func`, starting values `theta0`, the data `y` and `x`, and what type of variance to use `cov_type`.
#
# You need to use the `minimize` function, which takes the following inputs: the objective function `obj_func`, and the starting values `theta0`.
#
# You also need to finish up the `variance` function, which takes the function `func` (not the objective function), the data `y` and `x`, the results from the minimizer `result`, and finally what type of variance to calculate `cov_type`.

# %% [markdown]
# ## 2.a Estimate Parameters with `optimize.minimize`
#
# 1. Create a `lambda` function, `Q`, taking only one input, `theta`, and returning the negative mean loglikelihood.
#     * ***Hint:*** Watch this video to learn about functions in Python: https://youtu.be/watch?v=loF8zsPaIjs.
# 2. Evaluate `Q(theta0)` to test that it works.
# 3. Call `minimize`, starting from `theta0`, with options having `disp` set to `True` (you can do this by specifying setting `options = {'disp': True}`), and the optimization algorithm (`method`) set to `BFGS`.

# %%
# practice example with optimize.minimize

# 1. function handle to the objective 
Q = lambda theta : np.mean(lm.q(theta, y, x)) # just a function of one variable, theta

# 2. starting values 
print(theta0) # we defined these above, no need to redefine

# 3. call scipy minimize 
res = minimize(Q, theta0, options={'disp': True}, method='BFGS')
# Out:
# [[0.78886166]
#  [1.08601912]
#  [2.35222344]]
# Optimization terminated successfully.
#          Current function value: 1.568403
#          Iterations: 15
#          Function evaluations: 64
#          Gradient evaluations: 16
# C:\Users\JBH\AppData\Local\Temp\ipykernel_14732\2004663765.py:10: DeprecationWarning: Use of `minimize` with `x0.ndim != 1` is deprecated. Currently, singleton dimensions will be removed from `x0`, but an error will be raised in SciPy 1.11.0.
#   res = minimize(Q, theta0, options={'disp': True}, method='BFGS')

# %% [markdown]
# You should get
#
# Optimization terminated successfully.
#
#          Current function value: 1.568403
#
#          Iterations: 15
#
#          Function evaluations: 64
#
#          Gradient evaluations: 16

# %% [markdown]
# # Question 3: Standard Errors
#
# **Tasks**:
# * Fill in `estimation.estimate()`: For the estimate function, you need to read the documentation for the optimize.minimize function, to pass the obj_func and theta0 to that function.
#     * ***Bonus:*** Make sure that `estimate()` passes the inputs `options` and the optional `kwargs` correctly to `optimize.minimize`. The options struct can e.g. ask the optimizer to print or not print final convergence output by setting `options = {'disp': True}` (or `False`). The `kwargs` can include things like controlling which algorithm is used for optimization, e.g. `method='BFGS'`.
# * Fill in `estimation.variance()`: implement all three options for $\text{Avar}(\hat{\theta}$) described below.
#
# ## Theory: The Three Asymptotic Variance Estimators
#
# The log-likelihood function is a nonlinear function, which must in
# general be maximized numerically in order to obtain the ML estimates.
# In general, for $M$-estimators, we know that
# $$
# \sqrt{N}\left( \boldsymbol{\hat{\theta}}-\boldsymbol{\theta }_{0}\right)
# \overset{d}{\rightarrow} \mathcal{N} \left(\mathbf{0}, \mathbf{A}_{0}^{-1} \mathbf{B}_0 \mathbf{A}_{0}^{-1} \right).
# $$
#
# For Maximum Likelihood (ML) estimators specifically, the *Information Matrix
# Equality* holds, which implies that
# $$ \mathbf{A}_{0} = \mathbf{B}_{0}. $$
# This means that the asymptotic variance matrix simplifies so that
# $$ \mathbf{A}_{0}^{-1} \mathbf{B}_0 \mathbf{A}_{0}^{-1} = \mathbf{A}_{0}^{-1} = \mathbf{B}_{0}^{-1}.$$
#
# This means that we have three valid ways of estimating the asymptotic variance
# matrix of our parameter esimates:
#
# $\widehat{\text{Avar}}( \boldsymbol{\hat{\theta}})$ can be taken to be any
# of the three options
# 1. $\widehat{\text{Avar}}( \boldsymbol{\hat{\theta}}) = N^{-1} \hat{\mathbf{A}}^{-1}$: the `Hessian`,
# 2. $\widehat{\text{Avar}}( \boldsymbol{\hat{\theta}}) = N^{-1} \hat{\mathbf{B}}^{-1}$: the `Outer Product`,
# 3. $\widehat{\text{Avar}}( \boldsymbol{\hat{\theta}}) = N^{-1} \hat{\mathbf{A}}^{-1} \hat{\mathbf{B}} \hat{\mathbf{A}}^{-1} $: the `Sandwich`: viewed as a more "robust" option.
#
#
# where the components matrices are
# $$
# \begin{aligned}
# \quad \mathbf{\hat{A}}
#     &= -\frac{1}{N} \left[ \sum_{i=1}^{N}\mathbf{H}_{i}( \boldsymbol{\hat{\theta}}) \right]
# \\
# \quad  \mathbf{\hat{B}}
#     &= \frac{1}{N}
#         \left[ \sum_{i=1}^{N} \mathbf{s}_{i}( \boldsymbol{\hat{\theta}})
#                               \mathbf{s}_{i}( \boldsymbol{\hat{\theta}})^{\prime}
#         \right].
# \end{aligned}
# $$
#
#
# *Programming hint*: To calculate the variance you have to do the following:
#
# * `Hessian`: The optimizer will return the inverse of the Hessian, and can be accessed through `result.hess_inv`, which is $\mathbf{\hat{A}}^{-1}$. So for the `Hessian` variance, you would calculate:
# $$
# \widehat{\text{Avar}}( \boldsymbol{\hat{\theta}}) = \frac{1}{N}\mathbf{\hat{A}}^{-1}
# $$
# *Note*: You do not have to divide `result.hess_inv` by $N$, since we give the *average* loglikelihood to `minimize`.
# * `Outer Product`: the ex ante code computes the *numerical gradient* $N \times K$ matrix, `s`. You need to compute the $K \times K$ outer product of the scores,
# $ \mathbf{s}' \mathbf{s} = \sum_{i=1}^N \mathbf{s}_i \mathbf{s}_i', $
# ($\mathbf{s}_i$ is $K \times 1$ in this notation) and then use this to form $\hat{\mathbf{B}} = N^{-1} \mathbf{s}' \mathbf{s}$. Finally, calculate the variance using:
# $$
# \widehat{\text{Avar}}( \boldsymbol{\hat{\theta}}) = \frac{1}{N}\mathbf{\hat{B}}^{-1}
# $$

# %% [markdown]
# ## Question 3.a: The Outer Product
#
# Estimate parameters and compute standard errors using the `Outer Product` estimator. (This is the *default* variance estimator in `est.estimate`.)

# %%
results1 = est.estimate(lm.q, theta0, y, x)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.568403
#          Iterations: 15
#          Function evaluations: 64
#          Gradient evaluations: 16

# %%
label = ['beta 1', 'beta 2', 'sigma2'] #Recall our model -> we are estimating these parameters & the Avar(), ie. 'sigma^2'.
# Simulating the data, we specified sigma2 to be 3. We can't reject that this is the case
est.print_table(label, results1, title='Maximum Likelihood results', num_decimals=2)
# Out:
# Optimizer succeeded after 15 iter. (64 func. evals.). Final criterion:    1.568.
# Maximum Likelihood results
#         theta    se      t
# beta 1   0.99  0.31   3.23
# beta 2   1.36  0.40   3.42
# sigma2   2.91  0.23  12.66

# %% [markdown]
# Your table should look a little like this: <br>
#
# Maximum Likelihood results <br>
#
# |        |   theta |   se |   t |
# |--------|--------|------|------------|
# | beta 1 |   0.99 | 0.31 |       3.23 |
# | beta 2 |   1.36 | 0.40 |       3.42 |
# | sigma2 |   2.91 | 0.23 |      12.66 |

# %% [markdown]
# ### Question 3.b: The 'Sandwich' Estimator
#
# Compute standard errors using the `Sandwich` estimator.

# %%
results_san = est.estimate(lm.q, theta0, y, x, cov_type='Sandwich')
est.print_table(label, results_san, title='Maximum Likelihood results', num_decimals=3)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.568403
#          Iterations: 15
#          Function evaluations: 64
#          Gradient evaluations: 16
# Optimizer succeeded after 15 iter. (64 func. evals.). Final criterion:    1.568.
# Maximum Likelihood results
#         theta     se       t
# beta 1  0.986  0.284   3.474
# beta 2  1.358  0.336   4.045
# sigma2  2.911  0.186  15.613

# %% [markdown]
# Results should look like this:
#
# |        |   theta |    se |      t |
# |:-------|--------:|------:|-------:|
# | beta 1 |   0.986 | 0.284 |  3.475 |
# | beta 2 |   1.358 | 0.336 |  4.044 |
# | sigma2 |   2.911 | 0.186 | 15.619 |

# %% [markdown]
# ### Question 3.c: The 'Hessian' Estimator
#
# Compute standard errors using the `Hessian` estimator.

# %%
results_he = est.estimate(lm.q, theta0, y, x, cov_type='Hessian')
est.print_table(label, results_he, title='Maximum Likelihood results', num_decimals=3)
# Out:
# Optimization terminated successfully.
#          Current function value: 1.568403
#          Iterations: 15
#          Function evaluations: 64
#          Gradient evaluations: 16
# Optimizer succeeded after 15 iter. (64 func. evals.). Final criterion:    1.568.
# Maximum Likelihood results
#         theta     se      t
# beta 1  0.986  2.843  0.347
# beta 2  1.358  3.615  0.375
# sigma2  2.911  1.996  1.458

# %% [markdown]
# Results should look like this:
#
# |        |   theta |    se |      t |
# |:-------|--------:|------:|-------:|
# | beta 1 |   0.986 | 0.284 |  3.468 |
# | beta 2 |   1.358 | 0.362 |  3.755 |
# | sigma2 |   2.911 | 0.200 | 14.586 |

# %% [markdown]
# # Question 4: Monte Carlo Study.
#
# **Task:** Conduct a Monte Carlo study for different sample sizes.
#
# Conduct a Monte Carlo study of the Maximum Likelihood estimator. Try
# various values of $N$ to illustrate the consistency of the
# estimator. Is the estimator biased? Compare the three types of
# standard error estimates to the Monte Carlo sampling standard
# deviation. Is the estimator of $\sigma$ consistent?

# %%
NN = [5, 15, 50, 200]  # Sample size
S = 1000  # Number of replications
P = len(theta0)

# Initialize containers for all MX experiments
theta_n    = np.zeros((len(NN), P, S))
se_theta_n = np.zeros((len(NN), P, S))
MC_se      = np.zeros((len(NN), P))

# %%
# i is iteration number, N is the number of the sample size
for i, N in enumerate(NN): # loop over sample sizes 
    print(f'N = {N:5d}: {i+1}/{len(NN)}') 
    #first part = printing the number of observations, 
    #second part = which of the four [len(NN)] sample size we are looking at
    for s in range(S): # for each Monte Carlo replication 
        y, x = lm.sim_data(N, true_theta, rng) #True_theta contains our beta's and variance
        theta0 = lm.starting_values(y, x, ) # find starting values, and scale them slightly by 0.8
        results = est.estimate(lm.q, theta0, y, x ) # estimate parameters 
        
        theta_n[i, :, s] = results['theta_hat']
        se_theta_n[i, :, s] = results['se']
    
    MC_se[i, :] = np.std(theta_n[i,:,:], axis=1, ddof=1)
# Out:
# N =     5: 1/4
# Optimization terminated successfully.
#          Current function value: 0.649810
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.225089
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.447767
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.214453
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.877063
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.297336
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.586865
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.210473
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.039354
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.044517
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.614303
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.087865
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.272457
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.467292
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.448204
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.635735
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.307715
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.867605
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.315487
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.895557
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.329931
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.026200
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.596100
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.722870
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.367056
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.026357
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.413435
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.726881
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.578244
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.594822
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.656053
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.257727
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.323003
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.764981
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.132147
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 0.278220
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.846000
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.790342
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.830280
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.282181
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.449412
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.561638
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.792242
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.062346
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.204398
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.212837
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.628216
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.471432
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.021096
#          Iterations: 7
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.229337
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.208606
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.581612
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.606424
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.735574
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.317847
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.256470
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.186886
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.210230
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.697124
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 0.725049
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.272841
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.783103
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.831350
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.500783
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.822264
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.526305
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.252882
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.214809
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.149653
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.512536
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.671343
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.466851
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.291337
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.337926
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.878986
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.579010
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.225007
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.348335
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.819281
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.174211
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.609137
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 0.933698
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.441925
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.042774
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.147066
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.682568
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.397050
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.568207
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.367229
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.251271
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.590169
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.254743
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.795180
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 0.750762
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.762124
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.797769
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.044721
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.113760
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.056690
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.907380
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.753317
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.246755
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.851201
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.171609
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.154381
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.431248
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.058734
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.173378
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.299426
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.309115
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.980049
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.547943
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.491296
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.618105
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.492347
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.550705
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.329868
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.806500
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.397709
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.532177
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.069053
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.527956
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.147535
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.623371
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.656695
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.569728
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.084368
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.775451
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.134699
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.389980
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.813882
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.398033
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.517286
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.654417
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.428451
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.884900
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.290929
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.734106
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.701226
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.227434
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.061108
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 2.046648
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.805118
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.622194
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.969932
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.636888
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.593229
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.234053
#          Iterations: 7
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.877527
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.785946
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.205082
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.132816
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: -0.561771
#          Iterations: 6
#          Function evaluations: 56
#          Gradient evaluations: 14
# Optimization terminated successfully.
#          Current function value: 1.321993
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.082887
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.707989
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.969998
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.619791
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.389947
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: -0.445299
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.551321
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.945627
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.426034
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.339540
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.458478
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.423402
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.467085
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.881667
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.222281
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.175856
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.311953
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.894297
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.183392
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.478119
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.752908
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.140765
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 0.712941
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.639480
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.920898
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.150543
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.400418
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.775358
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.575413
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.646807
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.171608
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.352552
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.129260
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.909537
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.740299
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.644077
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.105346
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 0.507754
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.443017
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.873013
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.773798
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.173963
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.250246
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.186227
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.442694
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.552789
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 0.802702
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.724801
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.308285
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: -0.096684
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.369318
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.313328
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.307306
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 2.070234
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.776765
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.780795
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.469131
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.456764
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.760123
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.299414
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.513322
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.551101
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.462114
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.422174
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.240891
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.043078
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.196977
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.594568
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.519925
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.315907
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.674997
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.696562
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.879018
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.375300
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.016994
#          Iterations: 7
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.965791
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: -0.479172
#          Iterations: 7
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.623487
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.657911
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.607538
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.221056
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.893700
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.456696
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.459495
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.504626
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.766701
#          Iterations: 6
#          Function evaluations: 36
#          Gradient evaluations: 9
# Optimization terminated successfully.
#          Current function value: 1.241659
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.488365
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.423530
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.201228
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.403558
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.782954
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: -0.076997
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.656995
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.715920
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: -0.548727
#          Iterations: 7
#          Function evaluations: 40
#          Gradient evaluations: 10
# Optimization terminated successfully.
#          Current function value: 1.724824
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.085603
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.674804
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.832594
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.981040
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.323319
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.575562
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.950007
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.267586
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.966843
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.843611
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.476597
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.527495
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 0.786991
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.353899
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.398072
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.498707
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.101190
#          Iterations: 5
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 0.560491
#          Iterations: 4
#          Function evaluations: 24
#          Gradient evaluations: 6
# Optimization terminated successfully.
#          Current function value: 1.166374
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.284652
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.346555
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.382878
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.712554
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 0.904634
#          Iterations: 5
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.530038
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.870703
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.651980
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.184658
#          Iterations: 6
#          Function evaluations: 28
#          Gradient evaluations: 7
# Optimization terminated successfully.
#          Current function value: 1.826369
#          Iterations: 6
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.656538
#          Iterations: 5
#          Function evaluations: 32
#          Gradient evaluations: 8
# Optimization terminated successfully.
#          Current function value: 1.522773
#          Iterations: 4
#          Function evaluations: 28
#          Gradient evaluations: 7
# ...
# Optimization terminated successfully.
#          Current function value: 1.508053
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.664825
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.697366
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.545769
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.524223
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.587945
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.612100
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.641292
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.528024
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.592060
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.523933
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.612977
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.549164
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.658040
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.551459
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.564471
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.566137
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.451132
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.613748
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.606157
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.604447
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.542222
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.668791
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.654994
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.518077
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.623714
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.547385
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.632303
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.542533
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.557360
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.566786
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.652167
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.551763
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.543178
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.544255
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.642273
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.502566
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.514978
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.591820
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.601985
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.540424
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.545643
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.640659
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.592842
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.637595
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.623086
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.605523
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.619100
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.653904
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.613526
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.673249
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.672156
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.570178
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.635408
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.606949
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.604189
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.564214
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.567726
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.529043
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.599877
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.601375
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.508905
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.586747
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.595239
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.648868
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.576309
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.495888
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.590426
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.602670
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.677102
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.647341
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.600813
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.609068
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.600322
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.603324
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.552447
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.583568
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.566167
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.607924
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.596289
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.583582
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.606542
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.579090
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.559967
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.603684
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.618298
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.525080
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.536423
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.600974
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.618416
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.676867
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.706536
#          Iterations: 4
#          Function evaluations: 20
#          Gradient evaluations: 5
# Optimization terminated successfully.
#          Current function value: 1.576312
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4
# Optimization terminated successfully.
#          Current function value: 1.594344
#          Iterations: 3
#          Function evaluations: 16
#          Gradient evaluations: 4

# %% [markdown]
# ### Plotting the results

# %%
theta_n.shape
# First part -> sample size (4 different sample sizes)
# Second part -> estimations (beta1, beta2, sigma2)
# Third part -> the number of replications
# Out:
# (4, 3, 1000)

# %%
true_theta.shape
# [0] first row = beta1
# [1] second row = beta2
# [2] third row = sigma2
# Out:
# (3, 1)

# %%
i_theta = 1 # second beta, i.e. not the constant -> this is 1
theta_diff = theta_n[:, i_theta, :] - true_theta[i_theta, 0]
theta_diff.shape
# First element / rows: The different sample sizes
    # N=5,15,50,200 (we have four of these)
# Second element / columns: The number of replications
# Out:
# (4, 1000)

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.ravel() 

for i, ax in enumerate(axes):
    ax.hist(theta_diff[i,:], bins=20)
    ax.set_xlim(-10, 10)
    ax.set_xlabel('$\\hat{\\theta}_1 - \\theta^o_1$')

plt.tight_layout()

# %%
fig, ax = plt.subplots()
aa = np.linspace(0.3,0.5,len(NN))
for i, N in enumerate(NN): 
    xx = np.linspace(-6,6,30)
    ax.hist(theta_diff[i, :], bins=xx, alpha=aa[i], label=f'N = {N}', density=True)
ax.legend();

# %% [markdown]
# ### Same graph, scaled by $\sqrt{N}$

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.ravel() 
i_theta = 1 # second beta, i.e. not the constant 
theta_diff = theta_n[:, i_theta, :] - true_theta[i_theta, 0]

for i, ax in enumerate(axes):
    ax.hist(theta_diff[i,:] * np.sqrt(NN[i]), bins=30)
    ax.set_xlim(-15, 15)
    
    ax.set_xlabel(f'$\sqrt{{N}} (\\hat{{\\theta}}_{i_theta} - \\theta^o_{i_theta})$')
    ax.set_ylabel('Monte carlo samples')
    ax.set_title(f'N = {NN[i]}')

plt.tight_layout()

# %% [markdown]
# # Question 4: Alternative Minimization Algorithms
#
# **Task:** Estimate the model using alternative minimization algorithms (the input `method` to `minimize`). Compare how many function evaluations they take and whether they converge to the global minimum.
#
# * `BFGS`: The default algorithm (Newton with approximated Hessian and numerical gradients),
# * `CG`: Newton with numerical Hessian and gradients,
# * `Nelder-Mead`: Gradient-free optimizer,
# * `Powell`: Another gradient-free optimizer.
#
# ***Hint:*** `est.estimate()` accepts various extra args, which are by default just passed to `scipy.optimize.minimize`. Try alternatives for `method` (the algorithm).
#
# ***Note:*** The gradient-free optimizers do not return an inverse Hessian, so we can only compute the Outer Product variance matrix for those (unless we compute the Hessian numerically).

# %%
N = 100
y, x = lm.sim_data(N, true_theta, rng)
theta0 = lm.starting_values(y, x)*0.8 # make the minimisation problem a little harder

results_BFGS = est.estimate(lm.q, theta0, y, x) # the default option is method='BFGS'
results_CG   = est.estimate(lm.q, theta0, y, x, method='CG')
results_NM   = est.estimate(lm.q, theta0, y, x, method='Nelder-Mead')
results_PO   = est.estimate(lm.q, theta0, y, x, method='Powell')
# Out:
# Optimization terminated successfully.
#          Current function value: 1.532617
#          Iterations: 14
#          Function evaluations: 60
#          Gradient evaluations: 15
# Optimization terminated successfully.
#          Current function value: 1.532617
#          Iterations: 8
#          Function evaluations: 76
#          Gradient evaluations: 19
# Optimization terminated successfully.
#          Current function value: 1.532617
#          Iterations: 64
#          Function evaluations: 116
# Optimization terminated successfully.
#          Current function value: 1.532617
#          Iterations: 2
#          Function evaluations: 69

# %%
print(est.print_table(label, results_BFGS))
print(est.print_table(label, results_CG))
print(est.print_table(label, results_NM))
print(est.print_table(label, results_PO))
# Out:
# Optimizer succeeded after 14 iter. (60 func. evals.). Final criterion:    1.533.
# Results
#          theta      se        t
# beta 1  0.6397  0.2862   2.2351
# beta 2  0.4773  0.2920   1.6345
# sigma2  2.8084  0.1992  14.0965
# Optimizer succeeded after 8 iter. (76 func. evals.). Final criterion:    1.533.
# Results
#          theta      se        t
# beta 1  0.6397  0.2862   2.2354
# beta 2  0.4774  0.2920   1.6345
# sigma2  2.8084  0.1992  14.0964
# Optimizer succeeded after 64 iter. (116 func. evals.). Final criterion:    1.533.
# Results
#          theta      se        t
# beta 1  0.6397  0.2862   2.2351
# beta 2  0.4773  0.2921   1.6343
# sigma2  2.8084  0.1992  14.0963
# Optimizer succeeded after 2 iter. (69 func. evals.). Final criterion:    1.533.
# Results
#          theta      se        t
# beta 1  0.6396  0.2862   2.2348
# beta 2  0.4773  0.2921   1.6342
# sigma2  2.8084  0.1992  14.0963

# %% [markdown]
# Expected results (NB these are sensitive to how many times you've created synthetic data using the monte carlo simulations above - try re-running the entire notebook after restarting your kernel if your results dont match):

# %%
# --- BFGS ---
# Optimizer succeeded after 14 iter. (60 func. evals.). Final criterion:    1.533.
#Results
#         theta      se        t
# beta 1  0.6397  0.2862   2.2351
# beta 2  0.4773  0.2920   1.6345
# sigma2  2.8084  0.1992  14.0965
# --- CG ---
# Optimizer succeeded after 8 iter. (76 func. evals.). Final criterion:    1.533.
# Results
#          theta      se        t
# beta 1  0.6397  0.2862   2.2354
# beta 2  0.4774  0.2920   1.6345
# sigma2  2.8084  0.1992  14.0964
# --- Nelder-Mead ---
# Optimizer succeeded after 64 iter. (116 func. evals.). Final criterion:    1.533.
# Results
#          theta      se        t
# beta 1  0.6397  0.2862   2.2351
# beta 2  0.4773  0.2921   1.6343
# sigma2  2.8084  0.1992  14.0963
# --- Powell ---
# Optimizer succeeded after 2 iter. (69 func. evals.). Final criterion:    1.533.
# Results
#          theta      se        t
# beta 1  0.6396  0.2862   2.2348
# beta 2  0.4773  0.2921   1.6342
# sigma2  2.8084  0.1992  14.0963
